# %%
import spacy
import codecs

input_file = "../datasets/chapter01.txt"
with codecs.open(input_file, "r", encoding=None) as f:
    text = f.read()

nlp = spacy.load("it_core_news_sm")
doc = nlp(text)

# %%
i = 0
for sent in doc.sents:
    i +=1
    print(i, sent)
    if i == 10:
        break
# Out:
# 1 Quella specie di orologio da taschino, pesante e piuttosto ammaccato, serviva a dargli un’aria importante, dicevano.
# 2 Se lo portava di qua, di là, arrancando, su e giù per le strade di Taurette, in pratica ovunque, compagni inseparabili.
#
# 3 Per chi viveva da quelle parti era ormai abitudine non porre domande, e lui continuava a fare ciò che aveva da fare.
#
# 4 Qualsiasi cosa fosse.
#
# 5 Seurac si chiamava, ed era forse il più vecchio di quelli che se ne stavano laggiù.
# 6 Del suo orologio, nessuno immaginava a cosa servisse.
# 7 E nessuno avrebbe saputo cosa farsene.
# 8 Le lancette scandivano un tempo sbagliato e, sul, quadrante ingiallito, le ore non si leggevano più.
#
# 9 Ma andava bene così.
# 10 Per tutti.

# %%
len(max(doc.sents, key=len))
# Out:
# 55

# %%
len(min(doc.sents, key=len))
# Out:
# 2

# %%
doc2 = nlp("Mi chiamo Manuel. Sono nato a torino il 10 settembre 1984, l'anno in cui gli Scorpions risalivano le classifiche, in cui Orwell ambientò il suo capolavoro '1984'.")
displacy.render(doc2, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="4775" height="749.5" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">chiamo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Manuel.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# ...

# %%
from spacy import displacy
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">Mi chiamo
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Manuel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Sono nato a torino il 10 settembre 1984, l'anno in cui gli
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Scorpions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  risalivano le classifiche, in cui
# ...
